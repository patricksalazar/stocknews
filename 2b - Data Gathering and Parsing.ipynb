# %%
import numpy as np
import pandas as pd
import base64
import datetime

import spacy
import nltk
from nltk.tokenize.toktok import ToktokTokenizer

import re
from bs4 import BeautifulSoup
import unicodedata

import matplotlib.pyplot as plt
import seaborn as sns

import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls

# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # 2.1 Retrieve and Combine Stocks and Securities

# %%
pdata = pd.read_csv('./data/nyse/prices-split-adjusted.csv', encoding='utf-8')
pdata.head()
# Out:
#          date symbol        open       close         low        high  \
# 0  2016-01-05   WLTW  123.430000  125.839996  122.309998  126.250000
# 1  2016-01-06   WLTW  125.239998  119.980003  119.940002  125.540001
# 2  2016-01-07   WLTW  116.379997  114.949997  114.930000  119.739998
# 3  2016-01-08   WLTW  115.480003  116.620003  113.500000  117.440002
# 4  2016-01-11   WLTW  117.010002  114.970001  114.089996  117.330002
#
#       volume
# 0  2163600.0
# 1  2386400.0
# 2  2489500.0
# 3  2006300.0
# 4  1408600.0

# %%
secdata = pd.read_csv('./data/nyse/securities.csv', encoding='utf-8')
# rename column to allow join
secdata.rename(columns={'Ticker symbol': 'symbol'}, inplace=True)
secdata.head()
# Out:
#   symbol             Security SEC filings             GICS Sector  \
# 0    MMM           3M Company     reports             Industrials
# 1    ABT  Abbott Laboratories     reports             Health Care
# 2   ABBV               AbbVie     reports             Health Care
# 3    ACN        Accenture plc     reports  Information Technology
# 4   ATVI  Activision Blizzard     reports  Information Technology
#
#                 GICS Sub Industry   Address of Headquarters Date first added  \
# 0        Industrial Conglomerates       St. Paul, Minnesota              NaN
# 1           Health Care Equipment   North Chicago, Illinois       1964-03-31
# 2                 Pharmaceuticals   North Chicago, Illinois       2012-12-31
# 3  IT Consulting & Other Services           Dublin, Ireland       2011-07-06
# 4     Home Entertainment Software  Santa Monica, California       2015-08-31
#
#        CIK
# 0    66740
# 1     1800
# 2  1551152
# 3  1467373
# 4   718877

# %%
stock_data = pd.merge(pdata, secdata[['symbol','Security','GICS Sector', 'GICS Sub Industry']], on='symbol')
stock_data['diff']=(stock_data['close']-stock_data['open'])/stock_data['open']*100
stock_data.head()
# Out:
#          date symbol        open       close         low        high  \
# 0  2016-01-05   WLTW  123.430000  125.839996  122.309998  126.250000
# 1  2016-01-06   WLTW  125.239998  119.980003  119.940002  125.540001
# 2  2016-01-07   WLTW  116.379997  114.949997  114.930000  119.739998
# 3  2016-01-08   WLTW  115.480003  116.620003  113.500000  117.440002
# 4  2016-01-11   WLTW  117.010002  114.970001  114.089996  117.330002
#
#       volume              Security GICS Sector  GICS Sub Industry      diff
# 0  2163600.0  Willis Towers Watson  Financials  Insurance Brokers  1.952520
# 1  2386400.0  Willis Towers Watson  Financials  Insurance Brokers -4.199932
# 2  2489500.0  Willis Towers Watson  Financials  Insurance Brokers -1.228733
# 3  2006300.0  Willis Towers Watson  Financials  Insurance Brokers  0.987184
# 4  1408600.0  Willis Towers Watson  Financials  Insurance Brokers -1.743442

# %% [markdown]
# ### Evaluate data and find out how many stocks in energy/oil sector

# %%
stock_data[(stock_data['date'] == '2016-01-05') & (stock_data['GICS Sector'] == 'Energy')].describe()
# Out:
#              open       close         low        high        volume       diff
# count   36.000000   36.000000   36.000000   36.000000  3.600000e+01  36.000000
# mean    47.807778   47.860000   46.929166   48.365556  7.044572e+06   0.061717
# std     29.533748   29.666613   29.209861   29.905739  6.586727e+06   1.202284
# min      4.890000    5.010000    4.840000    5.090000  1.448800e+06  -2.691250
# 25%     25.602500   25.595000   24.917499   25.817501  2.777550e+06  -0.609361
# 50%     45.084999   44.724998   43.850000   45.774999  5.129350e+06   0.084438
# 75%     69.519997   69.657499   68.209997   70.014997  8.344725e+06   0.792391
# max    124.349998  125.169998  122.839996  126.089996  2.911390e+07   2.453988

# %% [markdown]
# #### Display 10 random stocks in the Energy sector to observe whether there is correlation

# %%
stock_data[stock_data['GICS Sector'] == 'Energy']['GICS Sub Industry'].unique()
# Out:
# array(['Oil & Gas Exploration & Production',
#        'Oil & Gas Equipment & Services', 'Integrated Oil & Gas',
#        'Oil & Gas Drilling',
#        'Oil & Gas Refining & Marketing & Transportation'], dtype=object)

# %%
plt_data = []
for stock in np.random.choice(stock_data[stock_data['GICS Sector'] == 'Energy']['symbol'].unique(), 10):
    energy_df = stock_data[stock_data['symbol'] == stock]
    
    plt_data.append(go.Scatter(
        x = energy_df['date'].values,
        y = energy_df['close'].values,
        name = stock
    ))
    
layout = go.Layout(dict(title = 'Closing prices of 10 energy stocks',
                       xaxis = dict(title = 'Month'),
                       yaxis = dict(title = 'Price'),
                       ), legend = dict(orientation = 'h'))
py.iplot(dict(data=plt_data, layout=layout), filename='basic-line')
# Out:
# <div>
#
#
#             <div id="58483afc-b9c3-4204-bae6-16ae44e92213" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("58483afc-b9c3-4204-bae6-16ae44e92213")) {
#                     Plotly.newPlot(
#                         '58483afc-b9c3-4204-bae6-16ae44e92213',
#                         [{"name": "FTI", "type": "scatter", "x": ["2010-01-04", "2010-01-05", "2010-01-06", "2010-01-07", "2010-01-08", "2010-01-11", "2010-01-12", "2010-01-13", "2010-01-14", "2010-01-15", "2010-01-19", "2010-01-20", "2010-01-21", "2010-01-22", "2010-01-25", "2010-01-26", "2010-01-27", "2010-01-28", "2010-01-29", "2010-02-01", "2010-02-02", "2010-02-03", "2010-02-04", "2010-02-05", "2010-02-08", "2010-02-09", "2010-02-10", "2010-02-11", "2010-02-12", "2010-02-16", "2010-02-17", "2010-02-18", "2010-02-19", "2010-02-22", "2010-02-23", "2010-02-24", "2010-02-25", "2010-02-26", "2010-03-01", "2010-03-02", "2010-03-03", "2010-03-04", "2010-03-05", "2010-03-08", "2010-03-09", "2010-03-10", "2010-03-11", "2010-03-12", "2010-03-15", "2010-03-16", "2010-03-17", "2010-03-18", "2010-03-19", "2010-03-22", "2010-03-23", "2010-03-24", "2010-03-25", "2010-03-26", "2010-03-29", "2010-03-30", "2010-03-31", "2010-04-01", "2010-04-05", "2010-04-06", "2010-04-07", "2010-04-08", "2010-04-09", "2010-04-12", "2010-04-13", "2010-04-14", "2010-04-15", "2010-04-16", "2010-04-19", "2010-04-20", "2010-04-21", "2010-04-22", "2010-04-23", "2010-04-26", "2010-04-27", "2010-04-28", "2010-04-29", "2010-04-30", "2010-05-03", "2010-05-04", "2010-05-05", "2010-05-06", "2010-05-07", "2010-05-10", "2010-05-11", "2010-05-12", "2010-05-13", "2010-05-14", "2010-05-17", "2010-05-18", "2010-05-19", "2010-05-20", "2010-05-21", "2010-05-24", "2010-05-25", "2010-05-26", "2010-05-27", "2010-05-28", "2010-06-01", "2010-06-02", "2010-06-03", "2010-06-04", "2010-06-07", "2010-06-08", "2010-06-09", "2010-06-10", "2010-06-11", "2010-06-14", "2010-06-15", "2010-06-16", "2010-06-17", "2010-06-18", "2010-06-21", "2010-06-22", "2010-06-23", "2010-06-24", "2010-06-25", "2010-06-28", "2010-06-29", "2010-06-30", "2010-07-01", "2010-07-02", "2010-07-06", "2010-07-07", "2010-07-08", "2010-07-09", "2010-07-12", "2010-07-13", "2010-07-14", "2010-07-15", "2010-07-16", "2010-07-19", "2010-07-20", "2010-07-21", "2010-07-22", "2010-07-23", "2010-07-26", "2010-07-27", "2010-07-28", "2010-07-29", "2010-07-30", "2010-08-02", "2010-08-03", "2010-08-04", "2010-08-05", "2010-08-06", "2010-08-09", "2010-08-10", "2010-08-11", "2010-08-12", "2010-08-13", "2010-08-16", "2010-08-17", "2010-08-18", "2010-08-19", "2010-08-20", "2010-08-23", "2010-08-24", "2010-08-25", "2010-08-26", "2010-08-27", "2010-08-30", "2010-08-31", "2010-09-01", "2010-09-02", "2010-09-03", "2010-09-07", "2010-09-08", "2010-09-09", "2010-09-10", "2010-09-13", "2010-09-14", "2010-09-15", "2010-09-16", "2010-09-17", "2010-09-20", "2010-09-21", "2010-09-22", "2010-09-23", "2010-09-24", "2010-09-27", "2010-09-28", "2010-09-29", "2010-09-30", "2010-10-01", "2010-10-04", "2010-10-05", "2010-10-06", "2010-10-07", "2010-10-08", "2010-10-11", "2010-10-12", "2010-10-13", "2010-10-14", "2010-10-15", "2010-10-18", "2010-10-19", "2010-10-20", "2010-10-21", "2010-10-22", "2010-10-25", "2010-10-26", "2010-10-27", "2010-10-28", "2010-10-29", "2010-11-01", "2010-11-02", "2010-11-03", "2010-11-04", "2010-11-05", "2010-11-08", "2010-11-09", "2010-11-10", "2010-11-11", "2010-11-12", "2010-11-15", "2010-11-16", "2010-11-17", "2010-11-18", "2010-11-19", "2010-11-22", "2010-11-23", "2010-11-24", "2010-11-26", "2010-11-29", "2010-11-30", "2010-12-01", "2010-12-02", "2010-12-03", "2010-12-06", "2010-12-07", "2010-12-08", "2010-12-09", "2010-12-10", "2010-12-13", "2010-12-14", "2010-12-15", "2010-12-16", "2010-12-17", "2010-12-20", "2010-12-21", "2010-12-22", "2010-12-23", "2010-12-27", "2010-12-28", "2010-12-29", "2010-12-30", "2010-12-31", "2011-01-03", "2011-01-04", "2011-01-05", "2011-01-06", "2011-01-07", "2011-01-10", "2011-01-11", "2011-01-12", "2011-01-13", "2011-01-14", "2011-01-18", "2011-01-19", "2011-01-20", "2011-01-21", "2011-01-24", "2011-01-25", "2011-01-26", "2011-01-27", "2011-01-28", "2011-01-31", "2011-02-01", "2011-02-02", "2011-02-03", "2011-02-04", "2011-02-07", "2011-02-08", "2011-02-09", "2011-02-10", "2011-02-11",  ...

# %% [markdown]
# ## 2.3 Group by data and securities

# %%
grp_data = stock_data.groupby(['GICS Sector', 'date']).agg({
    'Security': "count",
    "open": sum,
    "close": sum
})
grp_data.head()
# Out:
#                                    Security         open        close
# GICS Sector            date
# Consumer Discretionary 2010-01-04        77  2672.473763  2671.436019
#                        2010-01-05        78  2705.571271  2729.757742
#                        2010-01-06        78  2724.797536  2721.494277
#                        2010-01-07        78  2727.953311  2740.721386
#                        2010-01-08        78  2733.650218  2750.357443

# %%
grp_data.xs(key='Energy').head()
# Out:
#             Security         open        close
# date
# 2010-01-04        33  1525.897759  1551.516528
# 2010-01-05        33  1551.832163  1566.911977
# 2010-01-06        33  1565.173122  1584.721043
# 2010-01-07        33  1577.543497  1579.518125
# 2010-01-08        33  1572.397667  1594.940442

# %% [markdown]
# ### Similar the DJIA index methodology to get the average of the stocks by sector

# %%
# data was previously summed in previous row
grp_data['open']=grp_data['open']/grp_data['Security']
grp_data['close']=grp_data['close']/grp_data['Security']

# %%
grp_data['Daily Return']=(grp_data['close']-grp_data['open'])/grp_data['open']*100

# %% [markdown]
# ### 2.3.1 Plot the data to observe when the stock price had the greatest change

# %%
grouped = grp_data.groupby('date').agg({'Daily Return': ['std', 'min']}).reset_index()
grouped.head()
# Out:
#          date Daily Return
#                        std       min
# 0  2010-01-04     0.735353 -1.046991
# 1  2010-01-05     0.662124 -1.109534
# 2  2010-01-06     0.880933 -2.055354
# 3  2010-01-07     0.734142 -0.806164
# 4  2010-01-08     0.744911 -1.028062

# %%
g = grouped.sort_values(('Daily Return', 'std'), ascending=False)[:10]
g['text'] = 'Maximum price drop: ' + round(-1 * g['Daily Return']['min'], 2).astype(str)
g['Daily Return']['std'].values
# Out:
# array([1.92437035, 1.8775909 , 1.52651751, 1.51052325, 1.50756238,
#        1.49134958, 1.45367793, 1.40196412, 1.38990074, 1.35374364])

# %%
plt_data = go.Scatter(
    x = g['date'].values,
    y = g['Daily Return']['std'].values,
    mode='markers',
    marker=dict(
        size = 20 * g['Daily Return']['std'].values,
        color = g['Daily Return']['std'].values,
        colorscale='Portland',
        showscale=True
    ),
    text = g['text'].values
)
data = [plt_data]

layout = go.Layout(autosize=True,
                  title = 'Top 10 months by standard deviation of price change within a day',
                  hovermode='closest',
                  yaxis=dict(title='Daily Return', ticklen=5, gridwidth=2),
                  showlegend=False)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='stddev')
# Out:
# <div>
#
#
#             <div id="b7da8ed3-a401-4f0d-a8e9-b2f669014a55" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b7da8ed3-a401-4f0d-a8e9-b2f669014a55")) {
#                     Plotly.newPlot(
#                         'b7da8ed3-a401-4f0d-a8e9-b2f669014a55',
#                         [{"marker": {"color": [1.9243703471660338, 1.8775909026963156, 1.5265175145875949, 1.510523246433422, 1.507562378439277, 1.491349583324078, 1.4536779314208654, 1.4019641183416467, 1.3899007397337588, 1.3537436405124514], "colorscale": [[0.0, "rgb(12,51,131)"], [0.25, "rgb(10,136,186)"], [0.5, "rgb(242,211,56)"], [0.75, "rgb(242,143,56)"], [1.0, "rgb(217,30,30)"]], "showscale": true, "size": [38.48740694332068, 37.55181805392631, 30.530350291751898, 30.21046492866844, 30.151247568785543, 29.82699166648156, 29.07355862841731, 28.039282366832936, 27.798014794675176, 27.07487281024903]}, "mode": "markers", "text": ["Maximum price drop: 2.64", "Maximum price drop: -0.48", "Maximum price drop: 2.4", "Maximum price drop: 2.27", "Maximum price drop: -1.74", "Maximum price drop: 1.8", "Maximum price drop: 5.34", "Maximum price drop: 2.56", "Maximum price drop: -0.62", "Maximum price drop: 3.79"], "type": "scatter", "x": ["2016-10-27", "2011-10-04", "2016-11-10", "2015-08-24", "2011-08-09", "2016-11-09", "2014-07-29", "2016-06-27", "2015-10-02", "2011-10-07"], "y": [1.9243703471660338, 1.8775909026963156, 1.5265175145875949, 1.510523246433422, 1.507562378439277, 1.491349583324078, 1.4536779314208654, 1.4019641183416467, 1.3899007397337588, 1.3537436405124514]}],
#                         {"autosize": true, "hovermode": "closest", "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker" ...

# %% [markdown]
# ### 2.3.2 Observe the data for 1 specific sector, such as Energy

# %%
grp_data.xs(key='Energy').head()
# Out:
#             Security       open      close  Daily Return
# date
# 2010-01-04        33  46.239326  47.015652      1.678931
# 2010-01-05        33  47.025217  47.482181      0.971743
# 2010-01-06        33  47.429489  48.021850      1.248930
# 2010-01-07        33  47.804348  47.864186      0.125171
# 2010-01-08        33  47.648414  48.331529      1.433656

# %%
grouped = stock_data[stock_data['GICS Sector'] == 'Energy'].groupby('date').agg({'diff': ['std', 'max']}).reset_index()
grouped.head()
# Out:
#          date      diff
#                     std       max
# 0  2010-01-04  1.118377  4.664311
# 1  2010-01-05  1.530731  5.810902
# 2  2010-01-06  1.448154  5.695183
# 3  2010-01-07  0.853619  2.171178
# 4  2010-01-08  1.165558  3.550828

# %%
g = grouped.sort_values(('diff', 'std'), ascending=False)[:10]
g['text'] = 'Maximum price drop: ' + round(-1 * g['diff']['max'], 2).astype(str)
g['diff']['max'].values
# Out:
# array([ 7.76212495, 36.28912817, 26.70623145, 29.77099237, 21.78217822,
#        11.09018391, 18.47975505, 25.        , 16.73565937, 16.60550459])

# %%
plt_data = go.Scatter(
    x = g['date'].values,
    y = g['diff']['std'].values,
    mode='markers',
    marker=dict(
        size = 2*g['diff']['max'].values,
        color = g['diff']['max'].values,
        colorscale='Portland',
        showscale=True
    ),
    text = g['text'].values
)
data = [plt_data]

layout = go.Layout(autosize=True,
                  title = 'Top 10 months by standard deviation of price change within a day',
                  hovermode='closest',
                  yaxis=dict(title='Deviation in price', ticklen=5, gridwidth=2),
                  showlegend=False)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='stddev')
# Out:
# <div>
#
#
#             <div id="e537fbe6-d863-4ed9-91fb-a90db339f850" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e537fbe6-d863-4ed9-91fb-a90db339f850")) {
#                     Plotly.newPlot(
#                         'e537fbe6-d863-4ed9-91fb-a90db339f850',
#                         [{"marker": {"color": [7.762124952672143, 36.28912816691505, 26.70623145400592, 29.77099236641221, 21.782178217821787, 11.090183906880435, 18.479755051422643, 25.0, 16.73565937315197, 16.605504587155966], "colorscale": [[0.0, "rgb(12,51,131)"], [0.25, "rgb(10,136,186)"], [0.5, "rgb(242,211,56)"], [0.75, "rgb(242,143,56)"], [1.0, "rgb(217,30,30)"]], "showscale": true, "size": [15.524249905344286, 72.5782563338301, 53.41246290801184, 59.54198473282442, 43.564356435643575, 22.18036781376087, 36.959510102845286, 50.0, 33.47131874630394, 33.21100917431193]}, "mode": "markers", "text": ["Maximum price drop: -7.76", "Maximum price drop: -36.29", "Maximum price drop: -26.71", "Maximum price drop: -29.77", "Maximum price drop: -21.78", "Maximum price drop: -11.09", "Maximum price drop: -18.48", "Maximum price drop: -25.0", "Maximum price drop: -16.74", "Maximum price drop: -16.61"], "type": "scatter", "x": ["2016-02-08", "2016-01-14", "2016-03-03", "2016-03-02", "2016-01-20", "2016-11-30", "2016-01-21", "2016-04-12", "2016-01-22", "2016-03-04"], "y": [6.417303580151965, 6.03146447989765, 6.021758061313476, 5.789774718003848, 5.296905689519239, 4.983552406521124, 4.9789169476253266, 4.542642710914871, 4.5146077914330185, 4.411388187927761]}],
#                         {"autosize": true, "hovermode": "closest", "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker" ...

# %% [markdown]
# ## 2.4 Calculate Daily Returns and Standard Deviations

# %% [markdown]
# ### Calculate the means and standard deviations by sector

# %%
sigma = grp_data.groupby('GICS Sector').agg({'Daily Return':['mean', 'std', 'min']})
sigma
# Out:
#                             Daily Return
#                                     mean       std       min
# GICS Sector
# Consumer Discretionary          0.036876  0.929677 -4.206013
# Consumer Staples                0.051984  0.610403 -3.363354
# Energy                          0.013425  1.295804 -5.706094
# Financials                      0.032340  1.005465 -6.352469
# Health Care                     0.043555  0.877931 -3.805710
# Industrials                     0.046591  0.883032 -4.398844
# Information Technology          0.023120  0.913375 -4.560408
# Materials                       0.029144  0.947435 -4.702083
# Real Estate                     0.043639  0.997881 -4.673736
# Telecommunications Services    -0.005438  0.853520 -5.337575
# Utilities                       0.036095  0.794455 -4.151005

# %% [markdown]
# ### Generate the 1 and 2 sigma lower and upper limits

# %%
sigma['1sigmalow']=sigma.iloc[:,0]-sigma.iloc[:,1]
sigma['1sigmahi']=sigma.iloc[:,0]+sigma.iloc[:,1]
sigma['2sigmalow']=sigma.iloc[:,0]-(2*sigma.iloc[:,1])
sigma['2sigmahi']=sigma.iloc[:,0]+(2*sigma.iloc[:,1])
sigma
# Out:
#                             Daily Return                     1sigmalow  \
#                                     mean       std       min
# GICS Sector
# Consumer Discretionary          0.036876  0.929677 -4.206013 -0.892801
# Consumer Staples                0.051984  0.610403 -3.363354 -0.558419
# Energy                          0.013425  1.295804 -5.706094 -1.282379
# Financials                      0.032340  1.005465 -6.352469 -0.973125
# Health Care                     0.043555  0.877931 -3.805710 -0.834376
# Industrials                     0.046591  0.883032 -4.398844 -0.836441
# Information Technology          0.023120  0.913375 -4.560408 -0.890255
# Materials                       0.029144  0.947435 -4.702083 -0.918291
# Real Estate                     0.043639  0.997881 -4.673736 -0.954241
# Telecommunications Services    -0.005438  0.853520 -5.337575 -0.858958
# Utilities                       0.036095  0.794455 -4.151005 -0.758360
#
#                              1sigmahi 2sigmalow  2sigmahi
#
# GICS Sector
# Consumer Discretionary       0.966552 -1.822478  1.896229
# Consumer Staples             0.662387 -1.168822  1.272791
# Energy                       1.309229 -2.578183  2.605033
# Financials                   1.037805 -1.978589  2.043269
# Health Care                  0.921485 -1.712307  1.799416
# Industrials                  0.929623 -1.719473  1.812655
# Information Technology       0.936495 -1.803631  1.849871
# Materials                    0.976578 -1.865725  1.924013
# Real Estate                  1.041520 -1.952122  2.039400
# Telecommunications Services  0.848081 -1.712478  1.701601
# Utilities                    0.830551 -1.552815  1.625006

# %% [markdown]
# ## 2.5 Generate Labels based on whether sigma threshold passed

# %% [markdown]
# ### Setup labels for 1 and 2 sigma threshold of prices.

# %%
def onesigma(row):
    if row['Daily Return'] < sigma.xs(row.name[0])['1sigmalow'][0]:
        row['Label1Sig'] = -1
    elif row['Daily Return'] > sigma.xs(row.name[0])['1sigmahi'][0]:
        row['Label1Sig'] = 1
    else:
        row['Label1Sig'] = 0
    if row['Daily Return'] < sigma.xs(row.name[0])['2sigmalow'][0]:
        row['Label2Sig'] = -1
    elif row['Daily Return'] > sigma.xs(row.name[0])['2sigmahi'][0]:
        row['Label2Sig'] = 1
    else:
        row['Label2Sig'] = 0
    return row

# %%
grp_data['Label1Sig'] = 0
grp_data['Label2Sig'] = 0

# %%
sigma_df = grp_data.apply(onesigma, axis=1)

# %%
sigma_df.xs('Energy').head()
# Out:
#             Security       open      close  Daily Return  Label1Sig  Label2Sig
# date
# 2010-01-04      33.0  46.239326  47.015652      1.678931        1.0        0.0
# 2010-01-05      33.0  47.025217  47.482181      0.971743        0.0        0.0
# 2010-01-06      33.0  47.429489  48.021850      1.248930        0.0        0.0
# 2010-01-07      33.0  47.804348  47.864186      0.125171        0.0        0.0
# 2010-01-08      33.0  47.648414  48.331529      1.433656        1.0        0.0

# %%
sigma_df.xs('Energy').sort_values(by=['Daily Return'], ascending=False).head()
# Out:
#             Security       open      close  Daily Return  Label1Sig  Label2Sig
# date
# 2015-10-02      36.0  49.122500  51.973611      5.804083        1.0        1.0
# 2011-10-04      33.0  42.634050  45.061645      5.694030        1.0        1.0
# 2014-10-16      36.0  62.619371  65.776134      5.041193        1.0        1.0
# 2010-05-21      33.0  40.388387  42.200942      4.487812        1.0        1.0
# 2014-12-17      36.0  57.999861  60.550138      4.397041        1.0        1.0

# %%
sigma_df.reset_index()
sigma_df.head()
# Out:
#                                    Security       open      close  \
# GICS Sector            date
# Consumer Discretionary 2010-01-04      77.0  34.707451  34.693974
#                        2010-01-05      78.0  34.686811  34.996894
#                        2010-01-06      78.0  34.933302  34.890952
#                        2010-01-07      78.0  34.973760  35.137454
#                        2010-01-08      78.0  35.046798  35.260993
#
#                                    Daily Return  Label1Sig  Label2Sig
# GICS Sector            date
# Consumer Discretionary 2010-01-04     -0.038831        0.0        0.0
#                        2010-01-05      0.893951        0.0        0.0
#                        2010-01-06     -0.121230        0.0        0.0
#                        2010-01-07      0.468046        0.0        0.0
#                        2010-01-08      0.611169        0.0        0.0

# %% [markdown]
# # 2.5 Retrieve Reddit World News

# %%
nlp = spacy.load('en', parse=True, tag=True, entity=True)
tokenizer = ToktokTokenizer()
stopword_list = nltk.corpus.stopwords.words('english')
stopword_list.remove('no')
stopword_list.remove('not')

# %%
news_df = pd.read_csv('./data/RedditNews.csv', encoding='utf-8')
news_df.head()
# Out:
#          Date                                               News
# 0  2016-07-01  A 117-year-old woman in Mexico City finally re...
# 1  2016-07-01   IMF chief backs Athens as permanent Olympic host
# 2  2016-07-01  The president of France says if Brexit won, so...
# 3  2016-07-01  British Man Who Must Give Police 24 Hours' Not...
# 4  2016-07-01  100+ Nobel laureates urge Greenpeace to stop o...

# %% [markdown]
# ## 2.6 Text Preprocessing

# %% [markdown]
# ### 2.6.1 NLP methods

# %%
ps = nltk.porter.PorterStemmer()
def strip_html_tags(text):
    soup = BeautifulSoup(text, "html.parser")
    stripped_text = soup.get_text()
    return stripped_text

def remove_accented_chars(text):
    text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    return text

def remove_special_characters(text, remove_digits=False):
    pattern = r'[^a-zA-z0-9\s]'
    if remove_digits == True:
        pattern = r'[^a-zA-z\s]'
    
    text = re.sub(pattern, '', text)
    return text

def simple_stemmer(text):
    text = ' '.join([ps.stem(word) for word in text.split()])
    return text

def lemmatize_text(text):
    text = nlp(text)
    text = ' '.join([word.lemma_ if word.lemma_ != '-PRON-' else word.text for word in text])
    return text

def remove_stopwords(text, is_lower_case=False):
    tokens = tokenizer.tokenize(text)
    tokens = [token.strip() for token in tokens]
    if is_lower_case:
        filtered_tokens = [token for token in tokens if token not in stopword_list]
    else:
        filtered_tokens = [token for token in tokens if token.lower() not in stopword_list]
    filtered_text = ' '.join(filtered_tokens)    
    return filtered_text

text = news_df.iloc[0,1]
# remove_special_characters(text, True)
# simple_stemmer(text)
# lemmatize_text(text)
remove_stopwords(text)
# Out:
# '117-year-old woman Mexico City finally received birth certificate , died hours later. Trinidad Alvarez Lira waited years proof born 1898 .'

# %%
def normalize_corpus(corpus, html_stripping=True, contraction_expansion=True,
                     accented_char_removal=True, text_lower_case=True, 
                     text_lemmatization=True, special_char_removal=True, 
                     stopword_removal=True, remove_digits=True):
    
    normalized_corpus = []
    # normalize each document in the corpus
    for doc in corpus:
        # strip HTML
        if html_stripping:
            doc = strip_html_tags(doc)
        # remove accented characters
        if accented_char_removal:
            doc = remove_accented_chars(doc)
        # lowercase the text    
        if text_lower_case:
            doc = doc.lower()
        # remove extra newlines
        
        doc = re.sub(r'[\r|\n|\r\n]+', ' ',doc)
        # lemmatize text
        if text_lemmatization:
            doc = lemmatize_text(doc)
        # remove special characters and\or digits    
        if special_char_removal:
            # insert spaces between special characters to isolate them    
            special_char_pattern = re.compile(r'([{.(-)!}])')
            doc = special_char_pattern.sub(" \\1 ", doc)
            doc = remove_special_characters(doc, remove_digits=remove_digits)  
        # remove extra whitespace
        doc = re.sub(' +', ' ', doc)
        # remove stopwords
        if stopword_removal:
            doc = remove_stopwords(doc, is_lower_case=text_lower_case)
            
        normalized_corpus.append(doc)
        
    return normalized_corpus

# %% [markdown]
# #### NLP functions pulled from following article below
#
# Sarkar, Dipanjan (2018).  A Practitioner's Guide to Natural Language Processing (Part I) - Processing & Understanding Text.  Retrieved on 8/22/2019 from https://towardsdatascience.com/a-practitioners-guide-to-natural-language-processing-part-i-processing-understanding-text-9f4abfd13e72

# %%
# Run text based on corpus
news_df = news_df.replace({"b'": "", 'b"': ''}, regex=True)
corpus = normalize_corpus(news_df.iloc[:,1], text_lower_case=False, text_lemmatization=False, special_char_removal=False)
news_df['corpus'] = corpus

# %%
corpus[-5:]
# Out:
# ["Man goes berzerk Akihabara stabs everyone nearby : 6 dead , 12 injured '",
#  "Threat world AIDS pandemic among heterosexuals , report admits '",
#  "Angst Ankara : Turkey Steers Dangerous Identity Crisis '",
#  'UK : Identity cards \' could used spy people \' new children \' database may used identify likely future criminals. covert surveillance gone far ? "',
#  "Marriage , said , reduced status commercial transaction women could discarded husbands claiming discovered hidden defects . '"]

# %% [markdown]
# ### 2.6.2 Run Sentiment Analysis
# Instead of using the words in the articles to predict stocks we will also to use the sentiment score

# %% [markdown]
# #### 2.6.2.1 Extract Afinn and TextBlob sentiment

# %%
from afinn import Afinn
from textblob import TextBlob

af = Afinn()

# %%
def categorize_sentiment(score):
    if score > 0: 
        return 'positive'
    elif score < 0:
        return 'negative'
    else:
        return 'neutral'

# %%
def sentiment_score(row):
    article = row['News']
    row['sentiment'] = af.score(article)
    tb = TextBlob(article).sentiment
    row['polarity'] = tb.polarity
    row['subjectivity'] = tb.subjectivity
    return row

# %%
news_df = news_df.apply(sentiment_score, axis=1)

# %%
news_df[news_df['subjectivity'] > 0].head()
# Out:
#          Date                                               News  \
# 0  2016-07-01  A 117-year-old woman in Mexico City finally re...
# 3  2016-07-01  British Man Who Must Give Police 24 Hours' Not...
# 5  2016-07-01  Brazil: Huge spike in number of police killing...
# 6  2016-07-01  Austria's highest court annuls presidential el...
# 7  2016-07-01  Facebook wins privacy case, can track any Belg...
#
#                                               corpus  sentiment  polarity  \
# 0  117-year-old woman Mexico City finally receive...       -3.0 -0.066667
# 3  British Man Must Give Police 24 Hours ' Notice...      -12.0  0.111111
# 5  Brazil : Huge spike number police killings Rio...        1.0  0.400000
# 6  Austria ' highest court annuls presidential el...       -3.0 -0.200000
# 7  Facebook wins privacy case , track Belgian wan...        5.0  0.250000
#
#    subjectivity
# 0      0.366667
# 3      0.388889
# 5      0.900000
# 6      0.400000
# 7      0.150000

# %%
sigma_df[sigma_df['Label2Sig'] > 0].head()
# Out:
#                                    Security       open      close  \
# GICS Sector            date
# Consumer Discretionary 2010-03-22      78.0  37.350224  38.128713
#                        2010-04-22      78.0  40.976757  42.102060
#                        2010-05-21      78.0  36.059208  37.440705
#                        2010-05-25      78.0  36.425206  37.635892
#                        2010-06-02      78.0  37.803082  38.534569
#
#                                    Daily Return  Label1Sig  Label2Sig
# GICS Sector            date
# Consumer Discretionary 2010-03-22      2.084296        1.0        1.0
#                        2010-04-22      2.746197        1.0        1.0
#                        2010-05-21      3.831191        1.0        1.0
#                        2010-05-25      3.323759        1.0        1.0
#                        2010-06-02      1.934994        1.0        1.0

# %% [markdown]
# #### 2.6.2.2 Get Named Entities

# %%
text = corpus[0]
nlp = spacy.load('en', parse=True, tag=True, entity=True)
sentence_nlp = nlp(text)

# %%
def get_named_entities(news):
    entities = ''
    sentence_nlp = nlp(news)
    for word in sentence_nlp:
#         print('text',word.text,'pos', word.pos_, 'dep', word.dep_)
        ent_type = word.ent_type_
        if (ent_type != '') & (ent_type != 'DATE') & (ent_type != 'TIME') & (ent_type != 'QUANTITY') & (ent_type != 'ORDINAL') & (ent_type != 'CARDINAL'):
            entities += word.text + ' '
    return entities

# %%
news_df['Entities'] = news_df['News'].apply(get_named_entities)

# %%
def get_pos_tokens(news):
    pos = ''
    sentence_nlp = nlp(news)
    for word in sentence_nlp:
        if (word.pos_ == 'PROPN') | (word.pos_ == 'NOUN') | (word.pos_ == 'PRON') | (word.pos_ == 'VERB') | (word.pos_ == 'ADV'):
            pos += word.text + ' '          
    return pos

# %%
news_df['Tokens'] = news_df['News'].apply(get_pos_tokens)

# %%
news_df.head()
# Out:
#          Date                                               News  \
# 0  2016-07-01  A 117-year-old woman in Mexico City finally re...
# 1  2016-07-01   IMF chief backs Athens as permanent Olympic host
# 2  2016-07-01  The president of France says if Brexit won, so...
# 3  2016-07-01  British Man Who Must Give Police 24 Hours' Not...
# 4  2016-07-01  100+ Nobel laureates urge Greenpeace to stop o...
#
#                                               corpus  sentiment  polarity  \
# 0  117-year-old woman Mexico City finally receive...       -3.0 -0.066667
# 1      IMF chief backs Athens permanent Olympic host        1.0  0.000000
# 2        president France says Brexit , Donald Trump        3.0  0.000000
# 3  British Man Must Give Police 24 Hours ' Notice...      -12.0  0.111111
# 4  100+ Nobel laureates urge Greenpeace stop oppo...       -1.0  0.000000
#
#    subjectivity                            Entities  \
# 0      0.366667  Mexico City Trinidad Alvarez Lira
# 1      0.000000                     Athens Olympic
# 2      0.000000         France Brexit Donald Trump
# 3      0.388889                            British
# 4      0.000000                         Greenpeace
#
#                                               Tokens
# 0  woman Mexico City finally received birth certi...
# 1                       IMF chief backs Athens host
# 2  president France says Brexit won so can Donald...
# 3  Man Who Must Give Police Hours Notice Sex Thre...
# 4  Nobel laureates urge Greenpeace stop opposing ...

# %%
news_df.to_csv (r'.\cache\news_sentiment.csv', index = None, header=True)

# %% [markdown]
# ## 2.7 Observe the sentiment and polarity against the Stocks

# %%
# sigma_df = sigma_df.reset_index()[['date','GICS Sector', 'Label1Sig', 'Label2Sig']]
sigma_df = sigma_df.reset_index()
sigma_df[sigma_df['Label2Sig'] > 0].tail()
# Out:
#       GICS Sector        date  Security       open      close  Daily Return  \
# 19161   Utilities  2016-02-18      28.0  52.423571  53.315357      1.701116
# 19254   Utilities  2016-06-30      28.0  60.173929  61.368929      1.985910
# 19287   Utilities  2016-08-17      28.0  57.339286  58.282500      1.644970
# 19304   Utilities  2016-09-12      28.0  56.007143  56.980000      1.737023
# 19311   Utilities  2016-09-21      28.0  57.951071  59.162499      2.090433
#
#        Label1Sig  Label2Sig
# 19161        1.0        1.0
# 19254        1.0        1.0
# 19287        1.0        1.0
# 19304        1.0        1.0
# 19311        1.0        1.0

# %%
sdates = sigma_df[sigma_df['Label2Sig'] > 0]['date'].tail().values
sdates
# Out:
# array(['2016-02-18', '2016-06-30', '2016-08-17', '2016-09-12',
#        '2016-09-21'], dtype=object)

# %%
news_df[news_df['Date'] == sdates[0]].head()
# Out:
#             Date                                               News  \
# 3325  2016-02-18  Obama Going to Cuba; First Visit by U.S. Presi...
# 3326  2016-02-18  David Cameron blocks compulsory sex education ...
# 3327  2016-02-18  Uganda shuts down social media; candidates arr...
# 3328  2016-02-18  Japanese TV anchors lose their jobs for lack o...
# 3329  2016-02-18  Cairo court sentences 4-year-old boy to life i...
#
#                                                  corpus  sentiment  polarity  \
# 3325  Obama Going Cuba ; First Visit U.S. President ...        0.0  0.250000
# 3326  David Cameron blocks compulsory sex education ...       -1.0  0.000000
# 3327  Uganda shuts social media ; candidates arreste...       -3.0 -0.061111
# 3328  Japanese TV anchors lose jobs lack " fairness ...        0.0  0.000000
# 3329  Cairo court sentences 4-year-old boy life jail...       -8.0 -0.050000
#
#       subjectivity                            Entities  \
# 3325      0.333333  Obama Going Cuba First Visit U.S.
# 3326      0.000000                   David Cameron UK
# 3327      0.177778                             Uganda
# 3328      0.000000                           Japanese
# 3329      0.000000                Cairo - Middle East
#
#                                                  Tokens
# 3325  Obama Going Cuba First Visit U.S. President Ye...
# 3326  David Cameron blocks sex education classrooms UK
# 3327  Uganda shuts media candidates arrested electio...
# 3328      TV anchors lose jobs lack fairness reporting
# 3329  Cairo court sentences boy life jail murder dis...

# %% [markdown]
# ## 2.5.1 Combine news articles by date

# %%
grp_news_df = pd.DataFrame(columns=['date', 'positive','negative','neutral','polarity','subjectivity','corpus','entities','tokens'])
for name, group in news_df.groupby(['Date']):    
    articles=entities=tokens = ''
    positive=negative=neutral=polarity=subjectivity=0
    for row_index, row in group.iterrows():
        polarity += row['polarity']
        subjectivity += row['subjectivity']
        articles += row['News'] + ', '
        entities += row['Entities'] + ' '
        tokens += row['Tokens'] + ' '
        sentiment = row['sentiment']
        if sentiment > 0:
            positive += 1
        elif sentiment < 0:
            negative += 1
        else:
            neutral += 1
    
    size = (len(group))
    positive = positive/size
    negative = negative/size
    neutral = neutral/size
    polarity = polarity/size
    subjectivity = subjectivity/size
    grp_news_df = grp_news_df.append({'date': name, 'positive': positive,'negative': negative,'neutral': neutral,'polarity': polarity,'subjectivity': subjectivity,'news':articles,'entities':entities,'tokens':tokens}, ignore_index=True)

# %% [markdown]
# ## 2.6 Combine the news article with the Stock data

# %%
print(sigma_df.shape)
sigma_df.tail()
# Out:
# (19382, 8)
#       GICS Sector        date  Security       open      close  Daily Return  \
# 19377   Utilities  2016-12-23      28.0  57.009286  56.929643     -0.139702
# 19378   Utilities  2016-12-27      28.0  56.803928  56.929286      0.220685
# 19379   Utilities  2016-12-28      28.0  56.936429  56.307500     -1.104615
# 19380   Utilities  2016-12-29      28.0  56.508215  57.048928      0.956876
# 19381   Utilities  2016-12-30      28.0  57.091429  56.791071     -0.526099
#
#        Label1Sig  Label2Sig
# 19377        0.0        0.0
# 19378        0.0        0.0
# 19379       -1.0        0.0
# 19380        1.0        0.0
# 19381        0.0        0.0

# %%
print(grp_news_df.shape)
grp_news_df.tail()
# Out:
# (2943, 10)
#             date  positive  negative  neutral  polarity  subjectivity  corpus  \
# 2938  2016-06-27      0.24      0.48     0.28  0.003085      0.326705     NaN
# 2939  2016-06-28      0.28      0.36     0.36  0.035911      0.289912     NaN
# 2940  2016-06-29      0.28      0.48     0.24  0.038622      0.220205     NaN
# 2941  2016-06-30      0.16      0.64     0.20  0.022841      0.190421     NaN
# 2942  2016-07-01      0.20      0.68     0.12  0.008778      0.195556     NaN
#
#                                                entities  \
# 2938  RBS more than 8 %   Poland Poles UK   Scotland...
# 2939  Australia  French Google Drive  United Kingdom...
# 2940  Istanbul  Yemeni Al Saud  UK  Australian  Brit...
# 2941  Jamaica  Stephen Hawking  Boris Johnson Tory p...
# 2942  Mexico City Trinidad Alvarez Lira  Athens Olym...
#
#                                                  tokens  \
# 2938  Barclays RBS shares suspended trading tanking ...
# 2939  Scientists Australia You Want Save Great Barri...
# 2940  Explosion Airport Istanbul  president Terroris...
# 2941  Jamaica proposes marijuana dispensers tourists...
# 2942  woman Mexico City finally received birth certi...
#
#                                                    news
# 2938  Barclays and RBS shares suspended from trading...
# 2939  2,500 Scientists To Australia: If You Want To ...
# 2940  Explosion At Airport In Istanbul, Yemeni forme...
# 2941  Jamaica proposes marijuana dispensers for tour...
# 2942  A 117-year-old woman in Mexico City finally re...

# %%
combined_df = pd.merge(sigma_df, grp_news_df, on='date')
combined_df.head()
# Out:
#               GICS Sector        date  Security       open      close  \
# 0  Consumer Discretionary  2010-01-04      77.0  34.707451  34.693974
# 1        Consumer Staples  2010-01-04      34.0  34.337315  34.465189
# 2                  Energy  2010-01-04      33.0  46.239326  47.015652
# 3              Financials  2010-01-04      58.0  36.382588  36.701873
# 4             Health Care  2010-01-04      54.0  44.285254  44.513077
#
#    Daily Return  Label1Sig  Label2Sig  positive  negative  neutral  polarity  \
# 0     -0.038831        0.0        0.0      0.12      0.44     0.44 -0.017801
# 1      0.372404        0.0        0.0      0.12      0.44     0.44 -0.017801
# 2      1.678931        1.0        0.0      0.12      0.44     0.44 -0.017801
# 3      0.877577        0.0        0.0      0.12      0.44     0.44 -0.017801
# 4      0.514443        0.0        0.0      0.12      0.44     0.44 -0.017801
#
#    subjectivity  corpus                                           entities  \
# 0      0.289023     NaN   Indian McDonalds  Iceland nearly $ 5.7bn Brit...
# 1      0.289023     NaN   Indian McDonalds  Iceland nearly $ 5.7bn Brit...
# 2      0.289023     NaN   Indian McDonalds  Iceland nearly $ 5.7bn Brit...
# 3      0.289023     NaN   Indian McDonalds  Iceland nearly $ 5.7bn Brit...
# 4      0.289023     NaN   Indian McDonalds  Iceland nearly $ 5.7bn Brit...
#
#                                               tokens  \
# 0  airport scanners break child porn laws  eye cl...
# 1  airport scanners break child porn laws  eye cl...
# 2  airport scanners break child porn laws  eye cl...
# 3  airport scanners break child porn laws  eye cl...
# 4  airport scanners break child porn laws  eye cl...
#
#                                                 news
# 0  New airport scanners break child porn laws', I...
# 1  New airport scanners break child porn laws', I...
# 2  New airport scanners break child porn laws', I...
# 3  New airport scanners break child porn laws', I...
# 4  New airport scanners break child porn laws', I...

# %%
combined_df.to_csv (r'.\cache\data_parsed.csv', index = None, header=True)

# %% [markdown]
# #### Visual the classification of the 1 and 2 sigma st dev by sector

# %%
sig1df = combined_df.groupby(['GICS Sector','Label1Sig'], as_index=False)['date'].count()
sig2df = combined_df.groupby(['GICS Sector','Label2Sig'], as_index=False)['date'].count()
sig1df = sig1df.rename(columns={"Label1Sig": "action", "date": "onesigma"})
sig2df = sig2df.rename(columns={"Label2Sig": "action", "date": "twosigma"})
sigdf = pd.merge(sig1df, sig2df, on=['GICS Sector', 'action'])
sigdf
# Out:
#                     GICS Sector  action  onesigma  twosigma
# 0        Consumer Discretionary    -1.0       228        58
# 1        Consumer Discretionary     0.0      1205      1542
# 2        Consumer Discretionary     1.0       203        36
# 3              Consumer Staples    -1.0       206        51
# 4              Consumer Staples     0.0      1224      1548
# 5              Consumer Staples     1.0       206        37
# 6                        Energy    -1.0       228        49
# 7                        Energy     0.0      1202      1545
# 8                        Energy     1.0       206        42
# 9                    Financials    -1.0       210        58
# 10                   Financials     0.0      1238      1545
# 11                   Financials     1.0       188        33
# 12                  Health Care    -1.0       223        59
# 13                  Health Care     0.0      1196      1546
# 14                  Health Care     1.0       217        31
# 15                  Industrials    -1.0       209        57
# 16                  Industrials     0.0      1222      1541
# 17                  Industrials     1.0       205        38
# 18       Information Technology    -1.0       232        64
# 19       Information Technology     0.0      1178      1540
# 20       Information Technology     1.0       226        32
# 21                    Materials    -1.0       218        56
# 22                    Materials     0.0      1220      1545
# 23                    Materials     1.0       198        35
# 24                  Real Estate    -1.0       195        54
# 25                  Real Estate     0.0      1244      1548
# 26                  Real Estate     1.0       197        34
# 27  Telecommunications Services    -1.0       229        45
# 28  Telecommunications Services     0.0      1172      1559
# 29  Telecommunications Services     1.0       235        32
# 30                    Utilities    -1.0       223        45
# 31                    Utilities     0.0      1209      1559
# 32                    Utilities     1.0       204        32

# %%
pivdf = sigdf.pivot(index='GICS Sector',columns='action', values=['onesigma', 'twosigma'])
pivdf
# Out:
#                             onesigma            twosigma
# action                          -1.0   0.0  1.0     -1.0   0.0  1.0
# GICS Sector
# Consumer Discretionary           228  1205  203       58  1542   36
# Consumer Staples                 206  1224  206       51  1548   37
# Energy                           228  1202  206       49  1545   42
# Financials                       210  1238  188       58  1545   33
# Health Care                      223  1196  217       59  1546   31
# Industrials                      209  1222  205       57  1541   38
# Information Technology           232  1178  226       64  1540   32
# Materials                        218  1220  198       56  1545   35
# Real Estate                      195  1244  197       54  1548   34
# Telecommunications Services      229  1172  235       45  1559   32
# Utilities                        223  1209  204       45  1559   32
